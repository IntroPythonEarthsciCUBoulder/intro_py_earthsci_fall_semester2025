# %% [markdown]
# # Accessing list elements

# %%
mylist = []
print(type(mylist))
# Out:
# <class 'list'>

# %%
mylist = [1, 23]

# %%
mylist = ["Sep", 9, 2.025e3]

# %%
mylist[0]
# Out:
# 'Sep'

# %%
mylist[1:]
# Out:
# [9, 2025.0]

# %%
mylist[:2]
# Out:
# ['Sep', 9]

# %%
len(mylist)
# Out:
# 3
