# %%
print("Hi I am a cell")
# Out:
# Hi I am a cell

# %% [markdown]
# Hello, I am a markdown cell. Wait, what on earth is "markdown"?

# %% [markdown]
# # This is my title
#
# ## The big news
#
# ### The sub-text
#
# And some details...

# %%
print("hello world!")
# Out:
# hello world!
