# %% [markdown]
# # Python tuples and sets

# %%
mylist = [0, 1, 1, 2, 3, 5, 8]

# %%
mytuple = (0, 1, 1, 2, 3, 5, 8)

# %%
type(mylist)
# Out:
# list

# %%
type(mytuple)
# Out:
# tuple

# %%
mylist[2:5]
# Out:
# [1, 2, 3]

# %%
mytuple[2:5]
# Out:
# (1, 2, 3)

# %%
mylist[4] = 7777
print(mylist)
# Out:
# [0, 1, 1, 2, 7777, 5, 8]

# %%
mytuple[4] = 7777
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 mytuple[4] = 7777
#
# TypeError: 'tuple' object does not support item assignment

# %%
myset = set(mylist)
print(myset)
# Out:
# {0, 1, 2, 7777, 5, 8}

# %%
mydict = {"mydog" : "fido", "mycat" : "whiskers"}

# %%
print(mydict)
# Out:
# {'mydog': 'fido', 'mycat': 'whiskers'}
