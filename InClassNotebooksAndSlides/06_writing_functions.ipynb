# %% [markdown]
# *University of Colorado Boulder, GEOL 3600 Introduction to Python Programming for Geoscientists, Fall semester 2025*
#
# *In-class notebook for Monday 15 September*
#
# # Writing Functions
#
#
# ### Learning objectives
#
# - Describe why functions are useful
# - Define a function using `def`
# - Understand the difference between *defining* and *calling* a function
# - Write functions that take parameters
# - Write functions that return one or more values
# - Write functions that include optional parameters
# - Explain the difference between argument passing by copy or by reference, and what kinds of variables they apply to
# - Write a docstring to provide help for your function

# %% [markdown]
# ## <span style="color:green;">Warm-up exercises</span>

# %%
epochs = [
    'Paleocene',
    'Eocene',
    'Oligocene',
    'Miocene',
    'Pliocene',
    'Pleistocene',
    'Holocene',
    'Anthropocene',
]

# %% [markdown]
# Starting with the above list of geologic **epochs** in the Cenozoic Era, use list indexing and slicing to create:
#
# 1. A list of epochs in the Paleogene period (up to and including Oligocene)
# 2. A list of epochs in the Neogene period (Miocene and Pliocene)
# 3. A list of official epochs (those that have been formally ratified by the International Commission on Stratigraphy, which is all of them except Anthropocene)
# 4. A list that contains only the Anthropocene

# %% [markdown]
# <details>
#     <summary>
#         Answers:
#     </summary>
# <pre>
#
#     paleogene = epochs[:3]
#     neogene = epochs[3:-1]
#     cenozoic = epochs[:-1]
#     proposed = epochs[-1]
# </pre>
# These also work:
# <pre>
#
#     paleogene = epochs[0:3]
#     neogene = epochs[3:7]
#     cenozoic = epochs[0:7]
#     proposed = epochs[7]
# </pre>
# </details>

# %% [markdown]
# Create a Python dictionary containing the data in this table:
#
# | Site      | Basin area (km$^2$) |
# |-------------|----------------------------|
# | Heil-1 | 0.15 |
# | Heil-2   | 0.25 |
# | Geer   | 7.3 |
#
# The keys should be the site names (as strings), and the values should be the basin areas (as floats). Then use the dictionary to print out the area of the Geer site.

# %% [markdown]
# <details>
#     <summary>
#         Answers:
#     </summary>
# <pre>
#
# basin_areas = [
#     "Heil-1" : 0.15,
#     "Heil-2" : 0.25,
#     "Geer" : 7.3
# ]
# print(basin_areas["Geer"]
# </pre>

# %% [markdown]
# What are the data types of the two variables below?
#
# ```
# var1 = [3, 2, 1]
# var2 = (3, 2, 1)
# ```

# %% [markdown]
# <details>
#     <summary>
#         Answers:
#     </summary>
# `var1` is a list, `var2` is a tuple
# </details>

# %% [markdown]
# Which of the following lines of code will create an error?
# ```
# var1[1] = 4
# var2[1] = 4
# ```

# %% [markdown]
# <details>
#     <summary>
#         Answer:
#     </summary>
# The second line. `var2` is a tuple, and tuples are immutable: you cannot add or change any items once they are created.
# </details>

# %% [markdown]
# If you were to run the line `thing3 = {5, 4, 6, 5}`, what data type will `thing3` be and what items will it contain?

# %% [markdown]
# <details>
#     <summary>
#         Answers:
#     </summary>
# The curly braces define `thing3` as a `set`. Because a set can only can have unique values, it will contain the values, it will contain `{4, 5, 6}`.
# </details>

# %% [markdown]
# What values will the following return?
#
# ```
# pow(3, 2)
# pow(exp=3, base=2)
# ```

# %% [markdown]
# <details>
#     <summary>
#         Answers:
#     </summary>
# The first line returns 9 ($3^2$), and the second returns 8 ($2^3$).
# </details>

# %% [markdown]
# ## REVIEW: Functions and why are they useful?
#
# In the video lecture you learned how to use **functions**.
#
# Functions are *reusable pieces of code that can be 'called' using a function's name*.
#
# Functions can be called anywhere in a Python program, including calling functions within other functions.
#
# Functions are useful for at least three reasons:
#
# 1. Functions allow the same piece of code to run multiple times
# 2. Functions break longer programs up into smaller components
# 3. Functions can be shared and used by other programmers
#
# Every function has a function name. The function name is used when the function is called in a program.
#
# *Calling* a function means running a function.
#
# Functions can receive input from your main program. The inputs provided to a function are called *input arguments*. Arguments contain the data passed to a function as input.
#
# Functions can produce output. We say a function *returns* output to the program. The output of a function can be assigned to a variable for later use.

# %% [markdown]
# ## Defining a function using `def`

# %%
def say_hi():
    print("hello")

# %whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# say_hi     function    <function say_hi at 0x103ba6ca0>

# %% [markdown]
# Let's take that apart:
#
# **def** <br>
# def stands for *definition* and alerts the Python language interpreter that a function definition will follow.
# The keyword def needs to be the start of the line that declares the function.
#
# **say_hi** <br>
# Each function needs a name. The function name must start with a letter and is typically all lowercase (in Python, names that start with Uppercase are usually used to define classes). Function names can only contain letters, numbers and the underscore character.
#
# Note that any name will do, but it is much better to have a descriptor that people can understand.
#
# **code**<br>
# The function's code. These are the actual python actions that are being executed when the function is called. It is really important to note that this part is indented. The body of a Python function is defined by indentation.

# %% [markdown]
# ## Defining a function does not run it
#
# To run, or "call", a function, enter its name followed by parentheses:

# %%
say_hi()
# Out:
# hello

# %% [markdown]
# ## Function parameters
#
# A function may take one or more *parameters*.
#
# *Arguments* in the function call are matched to *parameters* in the function definition.
#
# Example: a function to convert temperature between Fahrenheit and Celsius:

# %%
def ctof(temp_in_c):
    temp_in_f = (temp_in_c * 1.8) + 32
    print(temp_in_c, 'C =', temp_in_f, 'F')

# %%
ctof(15.0)
# Out:
# 15.0 C = 59.0 F

# %% [markdown]
# Here, the input argument 15.0 is assigned to the function's `temp_in_c` parameter.

# %% [markdown]
# ## Function returns
#
# Often the purpose of a function is to perform a calculation and return the answer to the program that called it.

# %%
def ctof(temp_in_c):
    temp_in_f = (temp_in_c * 1.8) + 32
    return temp_in_f

# %%
# %whos
# Out:
# Variable          Type        Data/Info
# ---------------------------------------
# celsius_temp      float       10.0
# ctof              function    <function ctof at 0x103ba7600>
# distance          function    <function distance at 0x103ba5e40>
# fahrenheit_temp   NoneType    None
# say_hi            function    <function say_hi at 0x103ba6ca0>

# %%
celsius_temp = 10.0
fahrenheit_temp = ctof(celsius_temp)
print(celsius_temp, "deg C equals", fahrenheit_temp, "deg F")
# Out:
# 10.0 C = 50.0 F
# 10.0 deg C equals None deg F

# %% [markdown]
# ### Multiple parameters
#
# If you have multiple input parameters, they should be separated by commas in the function definition.

# %%
def distance(x_dist, y_dist):
    return (x_dist**2 + y_dist**2)**0.5

# %%
distance(3, 4)
# Out:
# 5.0

# %% [markdown]
# ## Scope
#
# "Scope" refers to the portion of a program in which a particular variable is defined and visible.
#
# ### Act locally
#
# The **scope** of a variable defined inside a function is **local**. A **local variable** exists *only* inside the function, and does not exist outside of the function.
#
# ```
# def area(r):
#     the_area = math.pi * r**2
#     print("Area of circle of radius", r, "is", the_area)
#
# print(the_area)  # uh oh, error!
# ```

# %%
def area(r):
    the_area = math.pi * r**2
    print("Area of circle of radius", r, "is", the_area)
    
print(the_area)  # uh oh, error!
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       2     the_area = math.pi * r**2
#       3     print("Area of circle of radius", r, "is", the_area)
# ----> 5 print(the_area)  # uh oh, error!
#
# NameError: name 'the_area' is not defined

# %% [markdown]
# ### Think globally (but not too much)
#
# Variables defined outside of any function have **global** scope.
#
# ```
# truncated_pi = 3.1416  # this variable has global scope
#
# def approx_area(r):
#     the_area = truncated_pi * r**2
#     print("Area of circle of radius", r, "is", the_area)
#
# print(approx_area(10.0))
# ```
#
# *WARNING: don't code like this! It's poor practice to rely on external global variables.*

# %%
truncated_pi = 3.1416  # this variable has global scope

def approx_area(r):
    the_area = truncated_pi * r**2 
    print("Area of circle of radius", r, "is", the_area)

print(approx_area(10.0))
# Out:
# Area of circle of radius 10.0 is 314.15999999999997
# None

# %% [markdown]
# ## Multiple returns
#
# You can return multiple values from a function. Here's an example of how:
#
# ```
# def f_to_ck(temp_in_f):
#
#     temp_in_c = temp_in_fahr * 1.8 + 32
#     temp_in_k = temp_in_c + 273.15
#
#     return temp_in_c, temp_in_k  # use commas to separate return items
#
#
# my_c_temp, my_k_temp = f_to_ck(68)
# ```

# %%
def f_to_ck(temp_in_f):

    temp_in_c = temp_in_f * 1.8 + 32
    temp_in_k = temp_in_c + 273.15
    
    return temp_in_c, temp_in_k  # use commas to separate return items


my_c_temp, my_k_temp = f_to_ck(68)

# %% [markdown]
# #### Quick quiz
#
# ```
# my_temps = f_to_ck(68)
# ```
#
# What data type is `my_temps`?
#
# How would you retrieve the temperature in $^\circ$C from `my_temps`?

# %%
my_temps = f_to_ck(68)

# %%
my_temps
# Out:
# (154.4, 427.54999999999995)

# %%
my_temps[0] = 78
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 my_temps[0] = 78
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ## <span style="color: green;"> IN-CLASS PRACTICE <span>

# %% [markdown]
# ### Example: calculating slope angle and gradient
#
# Imagine that you have used a digital topographic map to measure the horizontal distance between two points of 48 meters, and height difference of 4 meters. What is the slope gradient? What is the slope angle?

# %% [markdown]
# **slope angle** = angle between the surface and the horizontal (degrees or radians)
#
# **slope gradient** = *tangent* of angle = rise over run (often expressed in %)
#
# If you know the height and distance, you can find the gradient by calculating their ratio:
#
# $$\text{gradient} = \frac{\text{height}}{\text{distance}}$$
#
# If you know the gradient, you can find the angle by using the arctangent function:
#
# $$\text{angle} = \tan^{-1}(\text{gradient})$$
#
# where $\tan^{-1}$ means the arctangent function. NOTE: in the Python math module, the arctangent function is called `arctan`.
#
# Finally, if you know the angle (call it $\theta$), you can find the gradient by applying the tangent function:
#
# $$\text{gradient} = \tan\theta$$
#
# ![gradient_road_sign.png](attachment:202a699a-8c8d-421c-91f1-a3415b23b84d.png)

# %% [markdown]
# #### Using trigonometry to find slope angle or gradient:  "SOH-CAH-TOA"
#
# ![trig-01-136507350.jpg](attachment:2f30b912-434d-4921-87af-6fac702a2c26.jpg)
# (image from H K Wilfred Lee, Southwestern College)

# %% [markdown]
# #### EXERCISE: Write a function to convert a slope angle in percentage to degree
#
# - Import the `math` module.
# - Define a function called `calc_gradient` that takes the height and distance as inputs, and returns the gradient.
# - Define a function called `grad_to_angle` that takes the gradient as an input, and returns two values: the angle in degrees, and the angle in radians.
# - Run these functions with your measurements of height (4 m) and distance (48 m) and print out the results.

# %%
import math

def calc_gradient(height, horiz_distance):
    return height / horiz_distance

# %%
calc_gradient(100.0, 100.0)
# Out:
# 1.0

# %%
def grad_to_angle(gradient):
    """Calculate angle given gradient."""
    angle_in_radians = math.atan(gradient)
    angle_in_degrees = math.degrees(angle_in_radians)
    return angle_in_degrees, angle_in_radians

# %%
help(grad_to_angle)
# Out:
# Help on function grad_to_angle in module __main__:
#
# grad_to_angle(gradient)
#     Calculate angle given gradient.

# %%
print(math.pi / 4.0)
# Out:
# 0.7853981633974483

# %%
grad_to_angle(1.0)
# Out:
# (45.0, 0.7853981633974483)

# %%
help(math.radians)
# Out:
# Help on built-in function radians in module math:
#
# radians(x, /)
#     Convert angle x from degrees to radians.

# %% [markdown]
# ## Docstrings

# %% [markdown]
# ### Multi-line strings in Python
#
# When using a single pair of quotation marks to create a string, there's no way to include line breaks. For example, this works:
#
# ```
# hamlet_question = "To be or not to be"
# ```
#
# But this will generate an error:
#
# ```
# hamlet_question = "To be or not to be
#                    That is the question"
# ```
# because Python reaches the end of the first line without seeing an end-quote.
#
# To handle text that includes line breaks, Python allows for **long strings**. To create a long string, use triple quotation marks like so:
#
# ```
# hamlet_question = """To be or not to be
#                      That is the question"""
#
# print(hamlet_question)
# ```

# %%
hamq = """To be or not to be
That is the question"""

print(hamq)
# Out:
# To be or not to be
# That is the question

# %% [markdown]
# If you write a function, the first statement of the function body can optionally be a *string literal*.
# This string literal is the function’s documentation string, or **docstring**. It describes what the function does.
# The docstring serves as documentation of your function. It is part of programming best practices to include explanations with your code.
#
# You add the docstring directly after the function header.

# %%
# Docstrings can be as long as you like. There are several conventions for them; here's one:

def circle_area(radius):
    """
    Return the area of a circle of given radius.
    
    Parameters
    ----------
    radius : float
        The radius of the circle.
    
    Returns
    -------
    float : the area, in square units of whatever unit system was used for radius
    """
    return math.pi * radius**2
    
help(circle_area)
# Out:
# Help on function circle_area in module __main__:
#
# circle_area(radius)
#     Return the area of a circle of given radius.
#
#     Parameters
#     ----------
#     radius : float
#         The radius of the circle.
#
#     Returns
#     -------
#     float : the area, in square units of whatever unit system was used for radius

# %% [markdown]
# ## <span style="color: green;"> IN-CLASS PRACTICE <span>

# %% [markdown]
# Copy you code for the gradient and angle calculations, and add docstrings that describe what the functions do.
#
# Also add information about what parameters each function takes, and what they return.
#
# Then run the `help()` function on each function to verify that it displays your docstrings.

# %% [markdown]
# ## Optional further practice
#
# ### <span style="color: purple;">Motivating Problem: The importance of the slope and water flow in a river channel</span>

# %% [markdown]
# ![PointbarinMntStreAM_MNTMASSIVEREGION.jpeg](attachment:PointbarinMntStreAM_MNTMASSIVEREGION.jpeg)
#
# Mountain stream near Mnt Massive, Colorado. Photo I.Overeem

# %% [markdown]
# Type up a few observations on the stream you can make from this photo. Can you guess which way the water is flowing? What do you note about the water, the sediment in the river, and the shape of the channel?
#
# Can you identify the floodplain?
#
# Other noteworthy things?

# %% [markdown]
# ### <span style="color: purple;">Discharge</span>
#
# Discharge is the volume of water passing through a certain channel cross-section over a given time.
#
# $ Q = u w d $
#
# $Q$ in $m^3/s$ is the discharge
#
# $u$ in m/s is the velocity
#
# $w$ in m is the width
#
# $d$ in m is the depth

# %% [markdown]
# ### <span style="color: purple;">Streampower</span>

# %% [markdown]
# Intuitively, we think of steeper gullies or steeper river stretches to be more powerful. The slope is indeed a first-order control on how much sediment transport or erosion can occur in a certain stretch of gully or river channel. But it also depends on how much water is moving through.
#
# The combination of slope and water transport volume is captured in the geomorphological concept of **streampower**.
#
# Stream power is the amount of energy the water in a stream or a river is exerting on the bottom and the banks of the river.
#
# It is defined as follows:
#
# $ \Omega = \rho g Q S $
#
# water density $\rho = 1000$ in $kg/m^3$
#
# acceleration due to gravity $g = 9.8$ in $m/s^2$
#
# water discharge $Q$ in $m^3/s$
#
# slope $S$ in $m/m$

# %% [markdown]
# ## <span style="color: green;"> IN-CLASS PRACTICE <span>

# %%
# calculate discharge for a stream of 30m wide, 1.5m deep in which water flows at 1.2 m/s
# assign variables for discharge, Q, width, w,  depth, d,  velocity, u.

# %%
# assume you would want to this calculation for many stretches along a river where you take measurements

# write a function named discharge_calculator that returns discharge with arguments w,d,u 

# add a docstring to explain what it does

# %%
# call the discharge calculator
