# %% [markdown]
# *CU Boulder GEOL 3600 Introduction to Python Programming for Earth Scientists*
#
# *29 September 2025*

# %% [markdown]
# ## Review and practice with NumPy
#
# Note: this section assumes you have watched the short video lectures that introduce NumPy and its functionality. These can be found on canvas.
#
# ### About NumPy
# - NumPy [(https://numpy.org/)](https://numpy.org/) is a Python **package** for scientific computing
#
# - Not part of the Python language, but extremely useful in science applications
#
# - Provides an **array** data type for multi-dimensional arrays
#
# - Provides a host of other functions and capabilities
#
# - Free and open source
#
# ### About arrays
#
# Numpy `ndarrays` vs. Python `lists`:
#
# - A list can contain object of different types; in an ndarray, all objects have the same type (default `float`)
#
# - An `ndarray` can have multiple dimensions
#
# - When a mathematical operation is performed on one or more ndarrays, it is (usually) applied to *all* elements of the array at once.
#
# ### Ways to create new arrays
#
# - The `array()` function turns a list into an array. Ex: `myarr = np.array([1, 3, 2])`
#
# - Functions like `zeros(), ones(),` and `empty()` create an array of given size. Ex: `myarr = np.ones(5)`
#
# - The `arange()` acts like `range()` but generates an array. Ex: `myarr = np.arange(1, 10, 2)`
#
# - The `linspace()` and `logspace()` functions also create arrays with sequences of values. Ex: `myarr = linspace(0, 100, 25) # create a sequence of 25 numbers from 0 to 100`
#
#
#
#
# ### What you should be able to do
#
# - Import numpy (e.g., `import numpy as np`, then access functions as `np.array()`, etc.)
# - Create numpy array variables using `array`, `zeros`, `ones`, `arange`, and `linspace`
# - Use slicing to index values in an array
# - Perform operations on arrays
# - Use numpy mathematical functions such as `exp`, `sin`, etc.

# %% [markdown]
# ### <span style="color:green;">Exercises</span>
#
# #### <span style="color:green;">Creating arrays</span>

# %% [markdown]
# Create an array from a list using the numpy `array()` function.

# %%
a = np.array([2, 5, 6, 7])

# %% [markdown]
# Create an array using the `zeros()` function.

# %% [markdown]
# Create an array using the `ones()` function.

# %% [markdown]
# Create an array using `full()`.

# %% [markdown]
# Create arrays using `arange()`:
#
# - An array that starts at zero and increases by one, i.e., 0, 1, 2, 3, ...
# - An array that starts at something other than zero, e.g., 10, 11, 12, ...
# - An array that steps by 10, e.g., 0, 10, 20, 30 ...
# - An array that goes *backwards* from 10 to 1 (10, 9, 8, ...)
# - An array that steps by something < 1, e.g., 0, 0.1, 0.2, 0.3, ...

# %% [markdown]
# Create at least 3 arrays using the `linspace()` function.

# %% [markdown]
# Create an array using the `logspace()` function.

# %% [markdown]
# Create an array filled with `bool` values. (Hint: one way to do this is to use the `array()` function with a list of bools; another is to perform a comparison operation on an array, e.g., `myarray > 2`.)

# %% [markdown]
# #### <span style="color:green;">Operating on arrays</span>

# %% [markdown]
# Create an array called `arr` using `arange()`. Then try the following operations on your array values:
#
# - arr + 2
# - arr - 2
# - arr * 2
# - arr / 2
# - arr ** 2
# - arr % 2
# - arr > 2
# - arr < 2
# - arr == 2

# %% [markdown]
# Create two arrays of the same size. Then try combining them in different ways, as above: adding, subtracting, multiplying, comparing, etc.

# %% [markdown]
# Use numpy arrays to calculate the effective radiating temperature for the four inner planets. Make an array for solar irradiance values, and an array for albedo values. Then combine them in an expression that calculates an array of temperature values.
#
# As a reminder, the formula is:
#
# $$
# T = \left( \frac{S_0 (1 - a)}{4\sigma} \right)^{1/4}$$
#
# where $S_0$ is the irradiance, $a$ is the albedo, and $\sigma = 5.67\times 10^{-8}$ is the Stefan-Boltzmann constant.
#
# The input values for the planets are:
#
# | Planet name | Number     | Solar irradiance (W/m$^2$) | Albedo |
# |-------------|------------|----------------------------|--------|
# | Mercury | 1 | 9,083 | 0.068 |
# | Venus | 2 | 2,636 | 0.77 |
# | Earth | 3   | 1,360 | 0.31 |
# | Mars | 4    | 586   | 0.25 |

# %% [markdown]
# Put the above calculation inside a function. The function should take two input parameters: an array of irradiance values, and an array of albedo values. It should return an array of temperature values.
#
# Test your function to make sure it produces reasonable results.

# %% [markdown]
# #### <span style="color:green;">Array indexing and slicing</span>

# %% [markdown]
# Create an array with 10 elements. Then print out:
#
# - The value of element 3
# - Elements 0, 1, and 2
# - Elements 6, 7, 8, and 9
# - Elements 3, 4, and 5
# - The last element
# - The next-to-last element

# %% [markdown]
# Extract elements 2 through 7 and assign them to a new variable. What is the type of that variable? How many elements does it have?

# %% [markdown]
# #### <span style="color: green;">Using numpy functions: example of length of day</span>
#
#
# From [this wonderful site](https://www.timeanddate.com/sun/usa/boulder) we learn that Boulder's days are about 15 hours long at the summer solstice and 9 hours long at the winter solstice. That's a range of 6 hours and a period of one year (by definition!). Our formula for the length of day ("LOD", here represented in math by the symbol $L$) is therefore:
#
# $$L = L_\text{mean} + R \sin(2\pi t / P)$$
#
# where $L_\text{mean} = 12$ hours is the mean day length, $R = 6$ hours is the annual range, $t$ is the time in days since the vernal equinox ($\sim$March 21), and $P$ is the period in days (= 365, or really 365.25 if you want to want to be more accurate and factor in leap years).

# %%
# make an array to represent days of the year


# define variables for `period` (= 365 days), `mean_lod` (= 12 hours), 
# and `lod_range` (= 6 hours) 


# use `np.sin()` to calculate the length of day for each day of the year


# make a plot
import matplotlib.pyplot as plt

#plt.plot(NAME_OF_TIME_VARIABLE_HERE, NAME_OF_LOD_VARIABLE_HERE)
#plt.xlabel('Time from vernal equinox (days)')
#plt.ylabel('Length of day (hours)')

# %% [markdown]
# #### <span style="color:green;">Boolean indexing</span>

# %% [markdown]
# Recall how boolean operations work:
#
# ```
# a = -2
# a < 0  # returns True
# ```
#
# What happens if we do a comparison operation on an array?
# ```
# a = np.array([1, -3, 2, -4])
# is_negative = a < 0.0
# print(is_negative)
# type(is_negative)
# type(is_negative[0])
# ```
#
# Try running these lines of code. What type and size does the variable `is_negative` have? What data type are its elements?

# %% [markdown]
# We can use a boolean array as the index for another array, and the result will return a new array with just those values that are `True`.
#
# Example:
# ```
# a = np.array([1, -3, 2, -4])
# print(a[a < 0])
# ```
#
# Run the above lines to discover what kind of variable gets returned by the operation `a[a < 0]`.

# %% [markdown]
# Use boolean indexing to extract the temperatures of the planets that are above the freezing point (= 273.15K).

# %% [markdown]
# #### <span style="color:green;"> Multi-dimensional arrays</span>
#
# In earth science, it is not uncommon to work with 2D or even 3D arrays of data. Creating multi-dimensional arrays starts with the notion of using a `tuple` to specify the desired array dimensions. Example:
#
# ```
# a = np.zeros((3, 4)) # create a 3-row by 4-column array, all filled with zeros
# print(a)
# ```
#
# Indexing uses commas to distinguish between different dimensions. Example:
#
# ```
# a[1, 3] = 15.0 # row 1, column 3
# print(a)
# ```
#
# Create a 2D array with 4 rows and 5 columns, with each element equal to 1:
