# %% [markdown]
# # A refresher on functions
#
# *(CU Boulder GEOL 3600, fall semester 2025)*

# %%
temp_in_f = 53.

temp_in_c = (5 / 9) * (temp_in_f - 32)
temp_in_k = temp_in_c + 273.15
print(temp_in_f, "F equals", temp_in_c, "C and", temp_in_k, "K")
# Out:
# 53.0 F equals 11.666666666666668 C and 284.81666666666666 K

# %%
temp_in_f = 87.

temp_in_c = (5 / 9) * (temp_in_f - 32)
temp_in_k = temp_in_c + 273.15
print(temp_in_f, "F equals", temp_in_c, "C and", temp_in_k, "K")
# Out:
# 87.0 F equals 30.555555555555557 C and 303.7055555555555 K

# %%
temp_in_f = 23.

temp_in_c = (5 / 9) * (temp_in_f - 32)
temp_in_k = temp_in_c + 273.15
print(temp_in_f, "F equals", temp_in_c, "C and", temp_in_k, "K")
# Out:
# 23.0 F equals -5.0 C and 268.15 K

# %%
def ftock(temp_in_f):
    temp_in_c = (5 / 9) * (temp_in_f - 32)
    temp_in_k = temp_in_c + 273.15
    print(temp_in_f, "F equals", temp_in_c, "C and", temp_in_k, "K")

# %%
ftock(46)
# Out:
# 46 F equals 7.777777777777779 C and 280.92777777777775 K

# %%
ftock(11)
# Out:
# 11 F equals -11.666666666666668 C and 261.4833333333333 K

# %%
ftock(92)
# Out:
# 92 F equals 33.333333333333336 C and 306.4833333333333 K
