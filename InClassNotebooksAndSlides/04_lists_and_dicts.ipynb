# %% [markdown]
# # More on Python data types
#
# (Notebook prepared by Irina Overeem, September 2023; modified and extended by Greg Tucker, September 2025)
#
# **Learning Objectives for Python**
#
# - Work with comparison operators and `bool` variables
# - Use indexing and slicing to access items and subsets of Strings
# - Work with Lists (`list`)in Python
# - Use indexing and slicing to access items and subsets of Lists
# - Work with Dictionaries (`dict`) in Python
# - Create, store, access and manipulate data in a list or dictionary
#
# **Learning Objectives for Geoscience**
# - Learn how wildfires change soil properties and runoff
# - Infer how these changes influence the water balance
# - Learn how wildfires increase debris flow hazard
# - Make simple predictions of debris flow occurrence

# %% [markdown]
# ### <span style="color: green;">Getting started</span>
#
# From Canvas, download today's notebook: **04_lists_and_dicts.ipynb**
#
# Upload it to the **explore** Jupyter hub, and open it.

# %% [markdown]
# ## <span style="color: green;">REVIEW<span>
#
# Last time:
# - The assignment operator `=` assigns a value to a variable
# - The *type* of the variable depends on what is assigned to it
# - Types we met so far: `int`, `float`, `str`, and (briefly) `bool`
# - In a Jupyter notebook, the command `%whos` (which is not a Python command!) will list current variables
# - You can change the type of a variable using *typecasting* functions: `int()`, `float()`, `str()`, etc.

# %% [markdown]
# ### <span style="color: green;">QUICK WARM-UP <span>
#
# Create three variables, each of a different type:

# %% [markdown]
# Write code that typecasts the integer `4` into a text string:

# %% [markdown]
# ## Comparison operators and the `bool` data type
#
# ### `bool`
#
# A **boolean** variable, of type `bool`, can have only one of two possible values: `True` or `False`
#
# ### Comparison operators
#
# - A **comparison operator** compares two values and returns a `bool`: either `True` or `False`
# - Python comparison operators:
#   - Equal to `==`
#   - Uneqal to `!=`
#   - Greater than `>`
#   - Less than `<`
#   - Greater than or equal to `>=`
#   - Less than or equal to `<=`
# - You can combine comparison operations with `and` and `or`
# - You can test the inverse of a comparison using `not`

# %% [markdown]
# ### <span style="color: green;">EXERCISE<span>
#
# Try running examples of each of these comparison operators. Try assigning the result of a comparison operation to a variable. What is the type of that variable?

# %% [markdown]
# If there's extra time, try out `and`, `or`, and `not`, and experiment with compound comparison operations:

# %% [markdown]
# ## Working with strings
#
# - Define a string using single or double quotes: `mystr = "Earth is (almost) round"`
# - Find the length of a string with the `len()` function: `print(len(mystr))`
# - **Concatenate** strings with the `+` operator: `geodesy_fact = mystr + " but not quite"`

# %% [markdown]
# ### String indexing
#
# - Zero-based indexing: in `"Earth is (almost) round`, character 0 is `E`, character 1 is `a`, etc.
# - Retrieve the first character: `print(geodesy_fact[0])`
# - Use the colon `:` to get **slices** of a string:
#   - Retrieve the first $n$ characters: `print(geodesy_fact[:23]` NOTE: *up to but not including*
#   - Last $n$ characters: `print(geodesy_fact[23:]`
#   - Range of characters: `print(geodesy_fact[23:26]`

# %% [markdown]
# ### Splitting a string into words
#
# `print(geodesy_fact.split())`
#
# - `split()` is an example of a special kind of function called a **method** that acts on a particular **object**
# - Returns a data type called a **list** containing the individual words
# - By default, `split()` detects words based on spaces (you can change this)
# - We'll meet **lists** shortly!

# %% [markdown]
# ### <span style="color:green;">EXERCISE</span>
#
# Make a string variable containing `Chill out, dude!`
#
# Using indexing to print out the word `hi` inside this string.

# %% [markdown]
# ##  <span style="color: purple;"> Motivating Geoscience Problem: Post-Fire Erosion in Calwood Fire Area <span>
#
#
# #### Wldfires are increasing with climate change
# Wildfires are a yearly occurrence for the Western US, with thousands of fires sparking most commonly during August through November. Dry vegetation and lack of precipitation in these months enhance fire vulnerability. It has been shown that over the past few decades a warming climate lengthens the wildfire season (Dennison et al., 2014). Fire activity not only affects the organisms (inluding humans) that inhabit or use this land, but also impacts the post-fire geomorphological processes and sediment transport.
#
# ![denison2014smaller.jpg](attachment:e0709273-18fa-4240-bec2-719c290df492.jpg)
#
# Figure from Denison et al., 2014

# %% [markdown]
# #### Wildfires can make landscapes more prone to erosion
#
# The loss of vegetation directly affects the hydrologic cycle of the landscape; with vegetation wiped out, the interception of rainfall will decrease. When fires removes vegetation, it also affects the protection it provides the soil, enabling forces such as wind and rainsplash to affect the surface more intensely. Wildfires also directly make physical and chemical changes to the structure of soil. Fires enhances *soil water repellency* due to ash that affect pores, and due to chemical coatings to grains. <br>
#
# ![irina_calwood_infilt_photos_smaller.jpg](attachment:153ffdbd-7034-4988-bb0f-6cd848a89db9.jpg)

# %% [markdown]
# #### How Do Changes Affect the Water Balance Equation?
#
# The water balance in its simplest linear form is written as follows:
#
# $P = Q + ET + \Delta S $
#
# $P =$ precipitation in mm/time
#
# $Q =$ runoff in mm/time
#
# $ET =$ evapotranspiration in mm/time
#
# $\Delta S $ = change in groundwater storage due to infiltration in mm/time

# %% [markdown]
# ## <span style="color: green;"> IN-CLASS PRACTICE <span>

# %% [markdown]
# ### <span style="color: green;">Water balance in "normal" (unburned) conditions</span>
#
# Imagine we have a brief, heavy downpour, with rain coming down at 85 mm/hr for a few minutes.
#
# Assume you are in an area in the Front Range foothills where the normal infiltration capacity is 80 mm/hr.
#
# Assume that evapotranspiration is so small as to be practically zero.
#
# Step 1: Create variables for $P$, $\Delta S$ (infiltration), and $ET$, and assign the above values to them.
#
# Step 2: Use these variables together with arithmetic operators to calculate the runoff ($Q$), assigning the result to a variable.
#
# Step 3: Use the Python `print()` function to display the resulting runoff rate.

# %% [markdown]
# ### <span style="color: green;">Water balance for burned conditions</span>
#
# Now compare this with an area that was recently burned in a wildfire. The infiltration capacity is now down to 30 mm/hour.
#
# Follow the same steps as above, and compare the result.
#
# If the heavy rain lasts for 6 minutes, how much runoff (in mm) is generated from the unburned versus burned area?

# %% [markdown]
# So we have seen that after fires soil water repellency causes less water infiltration during rainstorms. The burns also cause less vegetation cover decreases canopy interception and evapotranspiration. Both of these factors resulting in more runoff and increased possibility of mass transport from the hillslopes into the drainage network. More runoff can cause *shallow landslides*, *debris flows*, and *downstream flash flooding*. The risk of debris flows is serious as large scale ones can be very destructive and transformative in the environment (Santi and Rengers, 2020).

# %% [markdown]
# #### Calwood Fire in 2020
#
# The Calwood Fire started about 3 miles northwest of Jamestown, in Boulder County, Colorado. Beginning October 16th, 2020, it burned for more than three weeks, until it was finally contained on November 11th of that year. The state of Colorado was in drought at the time. High winds and dry conditions together caused the fire to spread rapidly, at times consuming nearly 1000 acres an hour.  This wildfire in total burned ~10,113 acres and destroyed 20 homes. It impacted both the Lefthand Creek and St. Vrain Creek drainages. It ranged in elevation between ~2500 m of the highest rougher terrain to ~1700 m in the Foothills directly above HW93.
#
# ![irina_calwood_blaze.jpg](attachment:d3c7d4cb-e6f6-40fe-9eed-a041e5405f67.jpg)
#
# *photo I. Overeem*

# %% [markdown]
# #### Debris Flow
#
# A debris flow is a moving mass of loose mud, sand, soil, rock, water and air that travels down a slope under the influence of gravity. To be considered a debris flow, the moving material must be loose and capable of "flow," and at least 50% of the material must be sand-size particles or larger.
#
# Because debris flows travel relatively fast and carry a lot of mass, they are very destructive.
# Debris flows are a major hazard in the years directly after a fire. In the Western US, the USGS is mandated to make post-fire risk maps that show the likelihood of debris flow occurrence for diffferent streams.
#
# Here is the debris flow hazard map, constructed after the Calwood Fire. The red line shows the extent of the fire.
#
# ![debriflowhazardmapCalwood2020.png](attachment:debriflowhazardmapCalwood2020.png)
#
# USGS debris flow hazard map, published in October 2020, directly after Calwood Fire had been contained. The likelihood of occurrence depends on terrain steepness, stream order, burn severity and then depends on the rainfall intensity as a trigger to transport sediment.

# %% [markdown]
# Groups of CU Geology undergraduate students helped in 2021 and 2022 to collect data in several gullies of the terrain impacted by the Calwood Fire to assess burn severity, infiltration, vegetation regrowth.
# We will use python as an example of how to organize such small field datasets.

# %% [markdown]
# ## What is a List in Python?
#
# So far, we have been assigning single variables. What if you want to have many values, or a dataset with a single name? Lists in python are used to store multiple data items in a single *variable*.<br>
#
# Syntax: Lists are defined by using square brackets, with commas between the elements:
#
# ```
# a = [4.0, 2.5, 5.1]
# ```
#
# To create an empty list, use a pair of square brackets by itself:
# ```
# my_empty_list = []
# ```
#
# Lists are *mutable*, meaning that they can be changed or updated.
#
# You can add items to a list with `append()`:
# ```
# my_empty_list.append(["I am not empty!"])
# print(my_empty_list)
#
# ["I am not empty!"]
# ```
#
# You can combine ("concatenate") lists with the `+` operator:
# ```
# ralphie = [1]
# buff = ["yay!"]
# print(ralphie + buff)
#
# [1, "yay!"]
# ```
#
# Lists can contain different datatypes together, so it is a *compound data type*:
# ```
# some_list = ["apples", 3.1415926, 2025, True]
# ```
#
# You can access items in a list using *indexing*:
# ```
# print(some_list[0])
#
# "apples"
#
# print(some_list[2])
#
# 2025
#
# print(type(some_list[3]))
#
# bool
# ```
#
# You can access a sequence of items in a list using *slicing*:
# ```
# print(some_list[0:2])  # print elements 0 and 1 (NOT 2)
#
# ["apples", 3.1415926]
#
# print(some_list[:3])  # everything up to but not including item 3
#
# ["apples", 3.1415926, 2025]
#
# print(some_list[2:])  # from item 2 to the end
#
# [2025, True]
# ```

# %%
# Here I create a list of three gully names 
gully_names = ["Heil-Ranch-gully 1", "Heil-Ranch-gully2", "GeerCanyon" ]

# Here I create a list of the mapped burn severity in each of the three gullies
gully_burnseverity = ["severe", "moderate", "severe"]

# And I create a list of the upstream basin area of these three gullies in the Calwood fire area
# upstream basin area in km^2
A_gully1 = 0.1538 
A_gully2 = 0.2523
A_gully3 = 7.325

# so we can create a list of three floats
gully_areas = [0.1538, 0.2523, 7.325]

# %%
print(type(gully_names))
print(type(gully_areas))

# %%
# One very useful feature is that a list can contain multiple data types
# So I could also have all these separate items as follows
gully_data = [
    "Heil-Ranch-gully 1",
    0.1538,
    "Heil-Ranch-gully2",
    0.2523,
    "GeerCanyon",
    7.325
]

# %%
type(gully_data)

# %%
# interestingly a list datatype can also contain lists itself (this is called nesting)

gully_data_v2 = [
    ["Heil-Ranch-gully 1", 0.1538],
    ["Heil-Ranch-gully2", 0.2523],
    ["GeerCanyon", 7.325]
]

print(gully_data_v2)

# %% [markdown]
# ### <span style="color: green;"> EXERCISE <span>

# %% [markdown]
# Create a list of *normal* infiltration rates for the loamy gullies 1 and 2,
# and the sandy gully 3. Assume that the mean infiltration rate for the loamy soils
# is 60 mm/hr, and for sandy soils 80 mm/hr.

# %% [markdown]
# Then create a list called `post_fire_infilt_rate` that organizes the postfire infiltration rate per gully system.
#
# Mean infiltration rates as measured 3 months post-fire were, for the respective gullies:
# 2.25, 11.77, 3.5 mm/hr

# %% [markdown]
# In May 2021, the team did work in "Central Gulch". Its contributing area is 0.1515 km$^2$.
#
# Add this as a new item to the `gully_data` list using the `+` operator.
#
# Print it out to see if that worked

# %% [markdown]
# Create a more complete list called `gully_alldata`. It should be a nested list that combines the `gully_names`, `gully_areas`, `gully_burnseverity`, and the post-fire infiltration rates.

# %% [markdown]
# ### Subsetting lists

# %% [markdown]
# #### Using Indexes to Access List Items
# Once you have created a list, or have loaded an object that turns out to be a list, you may want to only use parts of the list, or get information on certain items of the list. So how do you access a list? <br>
#
# It turns out that one way of accessing certain items in a list is by using their *index*.
#
# In Python, the first item in a list has index 0, the second item has index 1, et cetera. <br>
# Remember, this is called zero-indexing.<br>
# It is important to know this is different in different programming languages!

# %%
print(gully_data)

# %%
# Let's say you'd want to select the basin area of the second gully, Heil-Ranch-gully2? 
# This is the fourth element, so it would have index 3 of the list.
gully_data[3]

# %%
# Recall we also made a nested list as an example
print(gully_data_v2)

# %%
# Our other nested list is the gully_all_data
print(gully_all_data)

# %%
# what index would you use to access the area of the first gully?

# %% [markdown]
# <details>
#     <summary>
#         Answer:
#     </summary>
#
#     gully_all_data[1][0]
#
#     This line of code fetches item 1 from gully_all_data, which is itself a list: [0.1538, 0.2523, 7.325]
#
#     Then it fetches item 0 from that list, which is the floating point value 0.1538
# </details>

# %%
# let's say you had a long list, and you wanted to know how long precisely
# you can use the len() function 
len(gully_data)

# what is the length of the nested list?

# %%
# You can use an integer value for your index.
# For example, if you want to know what is stored in the 5th list item:
n = 5
gully_data[n-1]

# %%
# You can also use negative indexing to get at the last element of a list
# -1 means the last item in the list
# -2 means the next-to-last item, etc.
gully_data[-1]

# %%
# %whos

# %% [markdown]
# ### <span style="color: green;"> EXERCISE</span>

# %% [markdown]
# Back to the water balance equation.
#
# Let's assume you have a 1 hr rainfall event of 30.0 mm/hr. (This happened in May 2021).
#
# Assume the evapotranspiration rate is zero.
#
# Assume you are in the Geer Canyon area.
#
# Calculate the runoff for this rain event considering the postfire infiltration rate. Use indexing of the `gully_all_data` list to do your calculation.
#
# What would be the total discharge at the downstream outlet of Geer Canyon? (Hint: you need to multiply runoff by the total drainage area, using consistent units.)

# %% [markdown]
# ### Slicing Lists

# %% [markdown]
# For long lists, it's often useful to select just a subset. You can do this using *slicing*, just as with strings.

# %%
print(gully_data)
gully_data[1:3] # items 1, 2 not including 3

# %%
print(gully_data)

#gully_data[-3:-1] # item -3, -2 not including -1

#or to get the last two items, use the colon
#gully_data[-2:]

# %% [markdown]
# ## Dictionaries
#
# Dictionaries allow you to store key-value pairs.
# Dictionaries are unique in that the keys can not be changed, but the values can be changed.
# In computer science jargon, the keys are *immutable*, but the values are *mutable*.
#
# Syntax: dictionaries use curly braces, the key is linked to its value by a colon, and key-value pairs are separated by a separated by commas.
#
# Example:
#
# ```
# calwood_fire_streams = {"Geer Canyon": "Lefthand Creek", "Calwood Creek": "South St Vrain" }
# ```
#
# So what's different from a list?
#
# Dictionaries are not indexed by a sequence of numbers, but indexed based on keys. Dictionaries are *associative arrays*.

# %%
# The streams draining the Calwood Fire go into different drainages
# One side is more used by recreationalists, and drains to Lefthand Creek.
# The other part goes into the South Saint Vrain, where an water intake of Longmont is located.
calwood_fire_streams = {"Geer Canyon": "Lefthand Creek", "Central Gulch": "South St Vrain" }

# %%
# the power of dictionaries is that you can inquire by key instead of index!

#access by key

calwood_fire_streams["Central Gulch"]

# %%
# adding an key-value pair is straightforward

calwood_fire_streams["Heil-Ranch-gully 1"] = "Lefthand Creek"

# %%
print(calwood_fire_streams)

# %% [markdown]
# ### <span style="color: green;"> EXERCISE <span>

# %% [markdown]
# Create a dictionary of the three gullies in which the keys are the gully names and the values are their associated infiltration rates. (Here's the table again for easy reference.)
#
#
# | Name      | Burn severity | Basin area (km$^2$) | Soil type | Infiltration rate (mm/h)
# |-------------|----------------------------|--------|--|--|
# | Heil-Ranch-1 | severe | 0.1538 | loam | 2.25 |
# | Heil-Ranch-2   | moderate | 0.2523 | loam | 11.77 |
# | GeerCanyon   | severe | 7.325 | sand | 3.5 |

# %% [markdown]
# Using your dictionary, print the infiltration rate of the Heil-Ranch-2 gully:

# %% [markdown]
# ##  <span style="color: purple;"> Motivating Geoscience Problem: Post-Fire Erosion in Calwood Fire Area <span>

# %% [markdown]
# ![DebrisFlowOccurrenceCaine1980.png](attachment:DebrisFlowOccurrenceCaine1980.png)
#
# So the first-generation empirical debris flow occurrence model was formulated by Caine 1980.
# It shows that debris flows only occurred in association with high-intensity, short-duration rain events.
#
# It postulated a threshold of:
#
# $$ I = 14.82 D^{-0.39} $$
#
# I =  intensity in mm/hr
# D = duration in hrs

# %% [markdown]
# ### <span style="color:green;">EXERCISE (if there is time)</span>

# %% [markdown]
# In May 2021, a rainstorm with an intensity of 30 mm/h and a duration of 1 hour fell on the Calwood Fire area. Using the above threshold formula, calculate whether or not this would have triggered a debris flow.
#
# (Hint: was the actual intensity of 30 mm/h greater than 14.82 times the duration to the -0.39 power?)
#
# Assign the boolean result (`True` or `False`) to a variable called `debris_flow_triggered`.

# %% [markdown]
# ## Review
#
# By this point, you should be able to:
#
# - Use comparison operators
# - Work with lists
# - Use indexing on strings and lists
# - Work with dictionaries

# %% [markdown]
# ## REFERENCES
#
# Dennison, P. E., S. C. Brewer, J. D. Arnold, and M. A. Moritz (2014), Large wildfire trends in the western United States, 1984–2011, Geophys. Res. Lett., 41, 2928–2933, doi:10.1002/2014GL059576.
#
# Santi, Paul M. & Rengers, Francis K. (2020). Wildfire and Landscape Change. Reference Module in Earth Systems and Environmental Sciences, Elsevier, ISBN 9780124095489,
# https://doi.org/10.1016/B978-0-12-818234-5.00017-1.
